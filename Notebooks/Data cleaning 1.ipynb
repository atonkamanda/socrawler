# %% [markdown]
# # Data cleaning and preproccessing

# %% [markdown]
# ### To acquire the data set

# %% [markdown]
# # https://github.com/github/CodeSearchNet

# %%
#importing libraries

import astor
import pandas as pd
from nltk.tokenize import RegexpTokenizer
from sklearn.model_selection import train_test_split
import ast
import glob
import re
from pathlib import Path

# %%
df = pd.concat([pd.read_json(f'python_train_{i}.jsonl',lines=True) for i in range(14)])

# %%
df.head()
# Out:
#                         repo                              path  \
# 0  ageitgey/face_recognition  examples/face_recognition_knn.py
# 1  ageitgey/face_recognition  examples/face_recognition_knn.py
# 2  ageitgey/face_recognition  examples/face_recognition_knn.py
# 3  ageitgey/face_recognition           face_recognition/api.py
# 4  ageitgey/face_recognition           face_recognition/api.py
#
#                          func_name  \
# 0                            train
# 1                          predict
# 2  show_prediction_labels_on_image
# 3                     _rect_to_css
# 4              _trim_css_to_bounds
#
#                                      original_string language  \
# 0  def train(train_dir, model_save_path=None, n_n...   python
# 1  def predict(X_img_path, knn_clf=None, model_pa...   python
# 2  def show_prediction_labels_on_image(img_path, ...   python
# 3  def _rect_to_css(rect):\n    """\n    Convert ...   python
# 4  def _trim_css_to_bounds(css, image_shape):\n  ...   python
#
#                                                 code  \
# 0  def train(train_dir, model_save_path=None, n_n...
# 1  def predict(X_img_path, knn_clf=None, model_pa...
# 2  def show_prediction_labels_on_image(img_path, ...
# 3  def _rect_to_css(rect):\n    """\n    Convert ...
# 4  def _trim_css_to_bounds(css, image_shape):\n  ...
#
#                                          code_tokens  \
# 0  [def, train, (, train_dir, ,, model_save_path,...
# 1  [def, predict, (, X_img_path, ,, knn_clf, =, N...
# 2  [def, show_prediction_labels_on_image, (, img_...
# 3  [def, _rect_to_css, (, rect, ), :, return, rec...
# 4  [def, _trim_css_to_bounds, (, css, ,, image_sh...
#
#                                            docstring  \
# 0  Trains a k-nearest neighbors classifier for fa...
# 1  Recognizes faces in given image using a traine...
# 2  Shows the face recognition results visually.\n...
# 3  Convert a dlib 'rect' object to a plain tuple ...
# 4  Make sure a tuple in (top, right, bottom, left...
#
#                                     docstring_tokens  \
# 0  [Trains, a, k, -, nearest, neighbors, classifi...
# 1  [Recognizes, faces, in, given, image, using, a...
# 2  [Shows, the, face, recognition, results, visua...
# 3  [Convert, a, dlib, rect, object, to, a, plain,...
# 4  [Make, sure, a, tuple, in, (, top, right, bott...
#
#                                         sha  \
# 0  c96b010c02f15e8eeb0f71308c641179ac1f19bb
# 1  c96b010c02f15e8eeb0f71308c641179ac1f19bb
# 2  c96b010c02f15e8eeb0f71308c641179ac1f19bb
# 3  c96b010c02f15e8eeb0f71308c641179ac1f19bb
# 4  c96b010c02f15e8eeb0f71308c641179ac1f19bb
#
#                                                  url partition
# 0  https://github.com/ageitgey/face_recognition/b...     train
# 1  https://github.com/ageitgey/face_recognition/b...     train
# 2  https://github.com/ageitgey/face_recognition/b...     train
# 3  https://github.com/ageitgey/face_recognition/b...     train
# 4  https://github.com/ageitgey/face_recognition/b...     train

# %%
df.shape
# Out:
# (412178, 12)

# %% [markdown]
# # We tokenize our data to make them easier for our model to process

# %%
def tokenize_docstring(text):
    """Gets filetered docstring tokens which help describe the function"""
    
    # Remove decorators and other parameter signatures in the docstring
    before_keyword, keyword, after_keyword = text.partition(':')
    before_keyword, keyword, after_keyword = before_keyword.partition('@param')
    before_keyword, keyword, after_keyword = before_keyword.partition('param')
    before_keyword, keyword, after_keyword = before_keyword.partition('@brief')
    
    if(after_keyword):    
        words = RegexpTokenizer(r'[a-zA-Z0-9]+').tokenize(after_keyword)
    else:
        before_keyword, keyword, after_keyword = before_keyword.partition('@')
        words = RegexpTokenizer(r'[a-zA-Z0-9]+').tokenize(before_keyword)
        
    # Convert all docstrings to lowercase
    new_words= [word.lower() for word in words if word.isalnum()]
    
    return new_words


def tokenize_code(text):
    """Gets filetered fucntion tokens"""
    
    # Remove decorators and function signatures till the def token
    keyword = 'def '
    before_keyword, keyword, after_keyword = text.partition(keyword)
    words = RegexpTokenizer(r'[a-zA-Z0-9]+').tokenize(after_keyword)
    
    # Convert function tokens to lowercase and remove single alphabet variables
    new_words= [word.lower() for word in words if (word.isalpha() and len(word)>1) or (word.isnumeric())]
    return new_words


def get_function_docstring_pairs(blob):
    "Extracts (function/method, docstring) pairs from a given code blob."
    
    pairs = []
    try:
        module = ast.parse(blob) # Converts the python code into an abstract syntx tree
        classes = [node for node in module.body if isinstance(node, ast.ClassDef)] # Retrieves classes from source code
        functions = [node for node in module.body if isinstance(node, ast.FunctionDef)] # Retrieves functions from the source code
        for _class in classes:
            functions.extend([node for node in _class.body if isinstance(node, ast.FunctionDef)]) # Retrieves functions from the classes extracted

        for f in functions:
            source = astor.to_source(f) # Convert the functions extracted into ast format so as to remove comments
            docstring = ast.get_docstring(f) if ast.get_docstring(f) else '' # Get docstring from fucntion definition if present
            function = source.replace(ast.get_docstring(f, clean=False), '') if docstring else source # function definition without any comments

            pairs.append((f.name,
                          f.lineno,
                          source,
                          ' '.join(tokenize_code(function)),
                          ' '.join(tokenize_docstring(docstring.split('\n\n')[0]))
                         ))
    except (AssertionError, MemoryError, SyntaxError, UnicodeEncodeError):
        pass
    return pairs


def get_function_docstring_pairs_list(blob_list):
    """apply the function `get_function_docstring_pairs` on a list of blobs"""
    return [get_function_docstring_pairs(b) for b in blob_list]

# %%
func_code = df.original_string.tolist()

# %%
func_doc = get_function_docstring_pairs_list(function_code)

# %%
len(func_doc)
# Out:
# 412178

# %%
df['pairs'] = func_doc
df.head()
# Out:
#                         repo                              path  \
# 0  ageitgey/face_recognition  examples/face_recognition_knn.py
# 1  ageitgey/face_recognition  examples/face_recognition_knn.py
# 2  ageitgey/face_recognition  examples/face_recognition_knn.py
# 3  ageitgey/face_recognition           face_recognition/api.py
# 4  ageitgey/face_recognition           face_recognition/api.py
#
#                          func_name  \
# 0                            train
# 1                          predict
# 2  show_prediction_labels_on_image
# 3                     _rect_to_css
# 4              _trim_css_to_bounds
#
#                                      original_string language  \
# 0  def train(train_dir, model_save_path=None, n_n...   python
# 1  def predict(X_img_path, knn_clf=None, model_pa...   python
# 2  def show_prediction_labels_on_image(img_path, ...   python
# 3  def _rect_to_css(rect):\n    """\n    Convert ...   python
# 4  def _trim_css_to_bounds(css, image_shape):\n  ...   python
#
#                                                 code  \
# 0  def train(train_dir, model_save_path=None, n_n...
# 1  def predict(X_img_path, knn_clf=None, model_pa...
# 2  def show_prediction_labels_on_image(img_path, ...
# 3  def _rect_to_css(rect):\n    """\n    Convert ...
# 4  def _trim_css_to_bounds(css, image_shape):\n  ...
#
#                                          code_tokens  \
# 0  [def, train, (, train_dir, ,, model_save_path,...
# 1  [def, predict, (, X_img_path, ,, knn_clf, =, N...
# 2  [def, show_prediction_labels_on_image, (, img_...
# 3  [def, _rect_to_css, (, rect, ), :, return, rec...
# 4  [def, _trim_css_to_bounds, (, css, ,, image_sh...
#
#                                            docstring  \
# 0  Trains a k-nearest neighbors classifier for fa...
# 1  Recognizes faces in given image using a traine...
# 2  Shows the face recognition results visually.\n...
# 3  Convert a dlib 'rect' object to a plain tuple ...
# 4  Make sure a tuple in (top, right, bottom, left...
#
#                                     docstring_tokens  \
# 0  [Trains, a, k, -, nearest, neighbors, classifi...
# 1  [Recognizes, faces, in, given, image, using, a...
# 2  [Shows, the, face, recognition, results, visua...
# 3  [Convert, a, dlib, rect, object, to, a, plain,...
# 4  [Make, sure, a, tuple, in, (, top, right, bott...
#
#                                         sha  \
# 0  c96b010c02f15e8eeb0f71308c641179ac1f19bb
# 1  c96b010c02f15e8eeb0f71308c641179ac1f19bb
# 2  c96b010c02f15e8eeb0f71308c641179ac1f19bb
# 3  c96b010c02f15e8eeb0f71308c641179ac1f19bb
# 4  c96b010c02f15e8eeb0f71308c641179ac1f19bb
#
#                                                  url partition  \
# 0  https://github.com/ageitgey/face_recognition/b...     train
# 1  https://github.com/ageitgey/face_recognition/b...     train
# 2  https://github.com/ageitgey/face_recognition/b...     train
# 3  https://github.com/ageitgey/face_recognition/b...     train
# 4  https://github.com/ageitgey/face_recognition/b...     train
#
#                                                pairs
# 0  [(train, 1, def train(train_dir, model_save_pa...
# 1  [(predict, 1, def predict(X_img_path, knn_clf=...
# 2  [(show_prediction_labels_on_image, 1, def show...
# 3  [(_rect_to_css, 1, def _rect_to_css(rect):\n  ...
# 4  [(_trim_css_to_bounds, 1, def _trim_css_to_bou...

# %%
# %%time 
df = df.set_index(['repo', 'path'])['pairs'].apply(pd.Series).stack()
df = df.reset_index()
df.columns = ['repo','path','_','pair']
# Out:
# CPU times: user 1min 51s, sys: 9.83 s, total: 2min 1s
# Wall time: 2min 35s

# %%
df.tail(200)
# Out:
#                      repo                           path  _  \
# 403261  mbarakaja/braulio                 braulio/cli.py  0
# 403262  mbarakaja/braulio                 braulio/cli.py  0
# 403263  mbarakaja/braulio                 braulio/cli.py  0
# 403264  mbarakaja/braulio                 braulio/cli.py  0
# 403265  mbarakaja/braulio                 braulio/cli.py  0
# ...                   ...                            ... ..
# 403456      pjuren/pyokit  src/pyokit/datastruct/read.py  0
# 403457      pjuren/pyokit  src/pyokit/datastruct/read.py  0
# 403458      pjuren/pyokit  src/pyokit/datastruct/read.py  0
# 403459      pjuren/pyokit  src/pyokit/datastruct/read.py  0
# 403460      pjuren/pyokit  src/pyokit/datastruct/read.py  0
#
#                                                      pair
# 403261  (changelog_file_option_validator, 1, def chang...
# 403262  (message_option_validator, 1, def message_opti...
# 403263  (current_version_option_validator, 1, def curr...
# 403264  (label_pattern_option_validator, 1, def label_...
# 403265  (release, 1, def release(ctx, bump, bump_type,...
# ...                                                   ...
# 403456  (getRelativeQualityScore, 1, def getRelativeQu...
# 403457  (reverse_complement, 1, def reverse_complement...
# 403458  (split, 1, def split(self, point=None):\n    "...
# 403459  (merge, 1, def merge(self, other, forceMerge=F...
# 403460  (to_fastq_str, 1, def to_fastq_str(self):\n   ...
#
# [200 rows x 4 columns]

# %% [markdown]
# # We restructure the dataset according to our needs

# %%
# %%time
df['function_name'] = df['pair'].apply(lambda p: p[0])
df['lineno'] = df['pair'].apply(lambda p: p[1])
df['original_function'] = df['pair'].apply(lambda p: p[2])
df['function_tokens'] = df['pair'].apply(lambda p: p[3])
df['docstring_tokens'] = df['pair'].apply(lambda p: p[4])
df = df[['repo', 'path', 'function_name', 'lineno', 'original_function', 'function_tokens', 'docstring_tokens']]
df['url'] = df[['repo', 'path', 'lineno']].apply(lambda x: 'https://github.com/{}/blob/master/{}#L{}'.format(x[0], x[1], x[2]), axis=1)
# Out:
# CPU times: user 24.7 s, sys: 49.9 ms, total: 24.7 s
# Wall time: 24.9 s

# %%
df.head()
# Out:
#                         repo                              path  \
# 0  ageitgey/face_recognition  examples/face_recognition_knn.py
# 1  ageitgey/face_recognition  examples/face_recognition_knn.py
# 2  ageitgey/face_recognition  examples/face_recognition_knn.py
# 3  ageitgey/face_recognition           face_recognition/api.py
# 4  ageitgey/face_recognition           face_recognition/api.py
#
#                      function_name  lineno  \
# 0                            train       1
# 1                          predict       1
# 2  show_prediction_labels_on_image       1
# 3                     _rect_to_css       1
# 4              _trim_css_to_bounds       1
#
#                                    original_function  \
# 0  def train(train_dir, model_save_path=None, n_n...
# 1  def predict(X_img_path, knn_clf=None, model_pa...
# 2  def show_prediction_labels_on_image(img_path, ...
# 3  def _rect_to_css(rect):\n    """\n    Convert ...
# 4  def _trim_css_to_bounds(css, image_shape):\n  ...
#
#                                      function_tokens  \
# 0  train train dir model save path none neighbors...
# 1  predict img path knn clf none model path none ...
# 2  show prediction labels on image img path predi...
# 3  rect to css rect return rect top rect right re...
# 4  trim css to bounds css image shape return max ...
#
#                                     docstring_tokens  \
# 0  trains a k nearest neighbors classifier for fa...
# 1  recognizes faces in given image using a traine...
# 2        shows the face recognition results visually
# 3  convert a dlib rect object to a plain tuple in...
# 4  make sure a tuple in top right bottom left ord...
#
#                                                  url
# 0  https://github.com/ageitgey/face_recognition/b...
# 1  https://github.com/ageitgey/face_recognition/b...
# 2  https://github.com/ageitgey/face_recognition/b...
# 3  https://github.com/ageitgey/face_recognition/b...
# 4  https://github.com/ageitgey/face_recognition/b...

# %%
# %%time
before_dedup = len(df)
df = df.drop_duplicates(['original_function'])
after_dedup = len(df)

print(f'Removed {before_dedup - after_dedup:,} duplicate rows')
# Out:
# Removed 10 duplicate rows
# CPU times: user 1.19 s, sys: 4.49 ms, total: 1.19 s
# Wall time: 1.26 s

# %%
# %%time
before_dedup = len(df)
df = df.drop_duplicates(['function_tokens'])
after_dedup = len(df)

print(f'Removed {before_dedup - after_dedup:,} duplicate rows')
# Out:
# Removed 557 duplicate rows
# CPU times: user 599 ms, sys: 157 µs, total: 599 ms
# Wall time: 614 ms

# %%
df.shape
# Out:
# (402894, 8)

# %%
def listlen(x):
    if not isinstance(x, list):
        return 0
    return len(x)

with_docstrings = df[df.docstring_tokens.str.split().apply(listlen) >= 3]
without_docstrings = df[df.docstring_tokens.str.split().apply(listlen) < 3]
print('Number of Function Snippets with docstring',len(with_docstrings))
print('Number of Function Snippets without docstring',len(without_docstrings))
# Out:
# Number of Function Snippets with docstring 375557
# Number of Function Snippets without docstring 27337

# %%
with_docstrings.to_csv('processed_full.csv')

# %%
with_docstrings.tail()
# Out:
#                  repo                           path            function_name  \
# 403455  pjuren/pyokit  src/pyokit/datastruct/read.py                 trimLeft
# 403456  pjuren/pyokit  src/pyokit/datastruct/read.py  getRelativeQualityScore
# 403457  pjuren/pyokit  src/pyokit/datastruct/read.py       reverse_complement
# 403458  pjuren/pyokit  src/pyokit/datastruct/read.py                    split
# 403459  pjuren/pyokit  src/pyokit/datastruct/read.py                    merge
#
#         lineno                                  original_function  \
# 403455       1  def trimLeft(self, amount):\n    """\n      Tr...
# 403456       1  def getRelativeQualityScore(self, i, score_typ...
# 403457       1  def reverse_complement(self, is_RNA=None):\n  ...
# 403458       1  def split(self, point=None):\n    """\n    Spl...
# 403459       1  def merge(self, other, forceMerge=False):\n   ...
#
#                                           function_tokens  \
# 403455  trimleft self amount if amount 0 return self s...
# 403456  getrelativequalityscore self score type illumi...
# 403457  reverse complement self is rna none sequence r...
# 403458  split self point none if point is none point l...
# 403459  merge self other forcemerge false if self sequ...
#
#                                          docstring_tokens  \
# 403455  trim this fastqsequence in place by removing a...
# 403456  get the realtive quality score i e the phred q...
# 403457              reverse complement this read in place
# 403458  split this read into two halves original seque...
# 403459  merge two reads by concatenating their sequenc...
#
#                                                       url
# 403455  https://github.com/pjuren/pyokit/blob/master/s...
# 403456  https://github.com/pjuren/pyokit/blob/master/s...
# 403457  https://github.com/pjuren/pyokit/blob/master/s...
# 403458  https://github.com/pjuren/pyokit/blob/master/s...
# 403459  https://github.com/pjuren/pyokit/blob/master/s...

# %%
# Number of unique repositories
print("Number of repositories -",len(list(set(with_docstrings['repo']))))
# Out:
# Number of repositories - 11991

# %%
# Getting the count of function tokens per function
with_docstrings['function_tokens_count'] = [len(item.split()) for item in list(with_docstrings['function_tokens'].values)]
# Out:
# /home/aton/anaconda3/envs/tf2/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Grouping entries by thie repository name
grouped = with_docstrings.groupby('repo')

# %%
# train, valid, test splits
train, valid = train_test_split(list(grouped), train_size=0.9, random_state=8081)
train, test = train_test_split(train, train_size=0.9, random_state=8081)

# %%
train = pd.concat([d for _, d in train]).reset_index(drop=True)
valid = pd.concat([d for _, d in valid]).reset_index(drop=True)
test = pd.concat([d for _, d in test]).reset_index(drop=True)

# %%
print(f'train set num rows {train.shape[0]:,}')
print(f'valid set num rows {valid.shape[0]:,}')
print(f'test set num rows {test.shape[0]:,}')
print(f'without docstring rows {without_docstrings.shape[0]:,}')
# Out:
# train set num rows 303,256
# valid set num rows 37,783
# test set num rows 34,518
# without docstring rows 27,337

# %%
train.head()
# Out:
#                          repo                    path   function_name  lineno  \
# 0            kennethreitz/env                  env.py      lower_dict       1
# 1            kennethreitz/env                  env.py        urlparse       1
# 2            kennethreitz/env                  env.py          prefix       1
# 3            kennethreitz/env                  env.py             map       1
# 4  aloetesting/aloe_webdriver  aloe_webdriver/util.py  string_literal       1
#
#                                    original_function  \
# 0  def lower_dict(d):\n    """Lower cases string ...
# 1  def urlparse(d, keys=None):\n    """Returns a ...
# 2  def prefix(prefix):\n    """Returns a dictiona...
# 3  def map(**kwargs):\n    """Returns a dictionar...
# 4  def string_literal(content):\n    """\n    Cho...
#
#                                      function_tokens  \
# 0  lower dict for in items try lower except attri...
# 1  urlparse keys none copy if keys is none keys k...
# 2  prefix prefix lower dict environ copy prefix p...
# 3  map kwargs lower dict environ copy for in kwar...
# 4  string literal content if in content and in co...
#
#                                     docstring_tokens  \
# 0              lower cases string keys in given dict
# 1  returns a copy of the given dictionary with ur...
# 2  returns a dictionary of all environment variab...
# 3  returns a dictionary of the given keyword argu...
# 4   choose a string literal that can wrap our string
#
#                                                  url  function_tokens_count
# 0  https://github.com/kennethreitz/env/blob/maste...                     10
# 1  https://github.com/kennethreitz/env/blob/maste...                     18
# 2  https://github.com/kennethreitz/env/blob/maste...                     22
# 3  https://github.com/kennethreitz/env/blob/maste...                     13
# 4  https://github.com/aloetesting/aloe_webdriver/...                     27

# %%
train.sort_values(by=['function_tokens_count'], inplace=True)
valid.sort_values(by=['function_tokens_count'], inplace=True)
test.sort_values(by=['function_tokens_count'], inplace=True)

# %%
train.to_csv('train_sorted.csv')
valid.to_csv('valid_sorted.csv')
test.to_csv('test_sorted.csv')

# %%
train.head()
# Out:
#                        repo                   path   function_name  lineno  \
# 89542     espressif/esptool  ecdsa/numbertheory.py            gcd2       1
# 74655         gwastro/pycbc   pycbc/conversions.py           chi_a       1
# 165400      SHDShim/pytheos     pytheos/eqn_bm3.py           bm3_k       1
# 177346   olsoneric/pedemath       pedemath/vec2.py        cross_v2       1
# 285898  asweigart/pyautogui  pyautogui/__init__.py  getPointOnLine       1
#
#                                         original_function  \
# 89542   def gcd2(a, b):\n    """Greatest common diviso...
# 74655   def chi_a(mass1, mass2, spin1z, spin2z):\n    ...
# 165400  def bm3_k(p, v0, k0, k0p):\n    """\n    calcu...
# 177346  def cross_v2(vec1, vec2):\n    """Return the c...
# 285898  def getPointOnLine(x1, y1, x2, y2, n):\n    ""...
#
#               function_tokens  \
# 89542            while return
# 74655              chi return
# 165400             return cal
# 177346           cross return
# 285898  getpointonline return
#
#                                          docstring_tokens  \
# 89542    greatest common divisor using euclid s algorithm
# 74655   returns the aligned mass weighted spin differe...
# 165400  calculate bulk modulus wrapper for cal k bm3 c...
# 177346  return the crossproduct of the two vectors as ...
# 285898  returns the x y tuple of the point that has pr...
#
#                                                       url  \
# 89542   https://github.com/espressif/esptool/blob/mast...
# 74655   https://github.com/gwastro/pycbc/blob/master/p...
# 165400  https://github.com/SHDShim/pytheos/blob/master...
# 177346  https://github.com/olsoneric/pedemath/blob/mas...
# 285898  https://github.com/asweigart/pyautogui/blob/ma...
#
#         function_tokens_count
# 89542                       2
# 74655                       2
# 165400                      2
# 177346                      2
# 285898                      2

# %% [markdown]
# # Now that our data are set up for the task, we can start the vectorization process
