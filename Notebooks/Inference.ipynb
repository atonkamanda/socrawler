# %%
import pandas as pd
from transformers import RobertaTokenizer, RobertaConfig, RobertaModel
import torch
import torch.nn as nn
import pickle

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce GTX 1060 3GB'

# %%
file_name = "code_tokens_100.pkl"
open_file = open(file_name, "rb")
code_vecs = pickle.load(open_file)
open_file.close()

# %%
tokenizer = RobertaTokenizer.from_pretrained("microsoft/codebert-base")
model = RobertaModel.from_pretrained("./python_model")

# %%
len(code_vecs)
# Out:
# 100

# %%
code_tensors = []

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
model.to(device)
# Out:
# RobertaModel(
#   (embeddings): RobertaEmbeddings(
#     (word_embeddings): Embedding(50265, 768, padding_idx=1)
#     (position_embeddings): Embedding(514, 768, padding_idx=1)
#     (token_type_embeddings): Embedding(1, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): RobertaEncoder(
#     (layer): ModuleList(
#       (0): RobertaLayer(
#         (attention): RobertaAttention(
#           (self): RobertaSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): RobertaSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
# ...

# %%
torch.cuda.empty_cache()

# %%
code_vecs[0]
# Out:
# {'input_ids': tensor([[    0,  9232,  2341,  1640, 21714,  1215, 41292,     6,  1421,  1215,
#          31575,  1215, 22609,  5214, 29802,     6,   295,  1215,   858,  8774,
#          19357,  5214, 29802,     6, 11269,   282,  1215,   337,  2977, 47579,
#           3512,  1215, 21512,  3934, 33760,  3876,  5214, 46659,  3256, 50118,
#           1437,  1437,  1437, 49434, 50118,  1437,  1437,  1437,  2393,  5069,
#             10,   449,    12,   858, 18759,  6611,  1380, 24072,    13,   652,
#           4972,     4, 50140,  1437,  1437,  1437,  4832, 46669,  2341,  1215,
#          41292,    35, 31826,    14,  6308,    10,  2849,    12, 48626,    13,
#            349,   684,   621,     6,    19,    63,   766,     4, 50140,  1437,
#           1437,  1437,  1437,    36, 22130,    11,  1300,  3260,     7,   192,
#           2341,  1215, 41292,  1246,  3907,  3184,    43, 50140,  1437,  1437,
#           1437,  1437, 32732,    35, 50118,  1437,  1437,  1437,  1437,  1437,
# ...

# %%
model(code_vecs[0]['input_ids'])[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\codebert\lib\site-packages\transformers\tokenization_utils_base.py in __getattr__(self, item)
#     240         try:
# --> 241             return self.data[item]
#     242         except KeyError:
#
# KeyError: 'size'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-e0954970940e> in <module>
# ----> 1 model(code_vecs[0],['input_ids'])[1]
#
# ~\anaconda3\envs\codebert\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
# ...

# %%
code_tensors = []

# %%
model(code_vecs[1]['input_ids'])[1]
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-25-72e269825606> in <module>
# ----> 1 model(code_vecs[1]['input_ids'])[1]
#
# ~\anaconda3\envs\codebert\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~\anaconda3\envs\codebert\lib\site-packages\transformers\models\roberta\modeling_roberta.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
# ...

# %%
code_tensors.append(model(code_vecs[i]['input_ids'])[1])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-24-b2a09cfeff48> in <module>
#       1 for i in range(1):
# ----> 2     code_tensors.append(model(code_vecs[i]['input_ids'])[1])
#       3
#
# ~\anaconda3\envs\codebert\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ...

# %%
code_tensors
# Out:
# [tensor([[-3.9592e-02,  3.2082e-02, -1.3196e-01,  5.3571e-01,  4.4671e-01,
#           -4.7317e-01, -1.6281e-01, -3.7309e-01, -1.4823e-01, -4.9893e-01,
#            4.6190e-01, -9.3659e-02, -9.7335e-02, -1.5963e-01,  4.7516e-01,
#            1.6548e-01,  5.8194e-01,  6.9257e-02, -1.6467e-02,  8.1208e-02,
#           -5.8535e-01, -3.7737e-02,  7.2033e-01, -1.4497e-01,  1.5167e-01,
#            1.9869e-01, -3.8060e-01, -4.8527e-01, -1.9563e-01, -7.7647e-01,
#           -3.3525e-02,  3.8826e-01, -3.8410e-01,  5.2195e-01,  3.1091e-01,
#           -4.4111e-01, -5.0254e-01, -3.2010e-01, -4.1159e-01,  7.5085e-01,
#           -1.4550e-01,  6.3541e-01, -4.4226e-02, -1.6334e-01, -2.4933e-01,
#            2.4670e-01,  3.2201e-01, -2.8897e-01,  1.6425e-01, -6.1522e-01,
#            1.5439e-02,  2.0161e-01,  4.5323e-01,  1.2760e-01,  5.4669e-01,
#            5.4889e-01, -2.0059e-02,  1.3617e-01, -4.1741e-01, -5.0672e-01,
# ...

# %%
code_tensors.append(model(code_vecs[i],return_tensors='pt')['input_ids'])[1])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-15-bac6bce8f776> in <module>
#       1 for i in range(10):
# ----> 2     code_tensors.append(model(tokenizer(code_vecs[i],return_tensors='pt')['input_ids'])[1])
#
# ~\anaconda3\envs\codebert\lib\site-packages\transformers\tokenization_utils_base.py in __call__(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2208         """
#    2209         # Input type checking for clearer error
# -> 2210         assert isinstance(text, str) or (
#    2211             isinstance(text, (list, tuple))
#    2212             and (
#
# ...

# %%
for i in range((len(code_list))):
    code_vecs.append((tokenizer(code_list[i],padding=True, truncation=True,return_tensors='pt').to(device)))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-99f6e97254d0> in <module>
# ----> 1 model(code_vecs[i]['input_ids'])[1]
#
# ~\anaconda3\envs\codebert\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~\anaconda3\envs\codebert\lib\site-packages\transformers\models\roberta\modeling_roberta.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     780
#     781         if attention_mask is None:
# ...
