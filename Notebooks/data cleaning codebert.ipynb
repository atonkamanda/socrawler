# %%
import pandas as pd

# %%
df = pd.concat([pd.read_json(f'python_train_{i}.jsonl',lines=True) for i in range(14)])

# %%
df
# Out:
#                             repo                              path  \
# 0      ageitgey/face_recognition  examples/face_recognition_knn.py
# 1      ageitgey/face_recognition  examples/face_recognition_knn.py
# 2      ageitgey/face_recognition  examples/face_recognition_knn.py
# 3      ageitgey/face_recognition           face_recognition/api.py
# 4      ageitgey/face_recognition           face_recognition/api.py
# ...                          ...                               ...
# 22173              pjuren/pyokit     src/pyokit/datastruct/read.py
# 22174              pjuren/pyokit     src/pyokit/datastruct/read.py
# 22175              pjuren/pyokit     src/pyokit/datastruct/read.py
# 22176              pjuren/pyokit     src/pyokit/datastruct/read.py
# 22177              pjuren/pyokit     src/pyokit/datastruct/read.py
#
#                              func_name  \
# 0                                train
# 1                              predict
# 2      show_prediction_labels_on_image
# ...

# %%
test = pd.concat([pd.read_json(f'python_test_0.jsonl',lines=True)])

# %%
test
# Out:
#                         repo                                   path  \
# 0            soimort/you-get      src/you_get/extractors/youtube.py
# 1            soimort/you-get       src/you_get/extractors/miomio.py
# 2            soimort/you-get     src/you_get/extractors/fc2video.py
# 3            soimort/you-get     src/you_get/extractors/fc2video.py
# 4            soimort/you-get  src/you_get/extractors/dailymotion.py
# ...                      ...                                    ...
# 22171  un33k/django-toolware              toolware/utils/generic.py
# 22172  un33k/django-toolware              toolware/utils/generic.py
# 22173  un33k/django-toolware              toolware/utils/generic.py
# 22174  un33k/django-toolware              toolware/utils/generic.py
# 22175  un33k/django-toolware              toolware/utils/generic.py
#
#                       func_name  \
# 0      YouTube.get_vid_from_url
# 1          sina_xml_to_url_list
# 2                      makeMimi
# ...

# %%
valid = pd.concat([pd.read_json(f'python_valid_0.jsonl',lines=True)])

# %%
valid
# Out:
#                       repo                                             path  \
# 0         openai/baselines                         baselines/deepq/deepq.py
# 1         openai/baselines                         baselines/deepq/deepq.py
# 2         openai/baselines                       baselines/common/models.py
# 3         openai/baselines                       baselines/common/models.py
# 4         openai/baselines                       baselines/common/models.py
# ...                    ...                                              ...
# 23102    xnuinside/clifier                               clifier/clifier.py
# 23103    xnuinside/clifier                               clifier/clifier.py
# 23104  tklovett/PyShirtsIO                           interactive_console.py
# 23105          ibelie/typy  typy/google/protobuf/internal/python_message.py
# 23106          ibelie/typy  typy/google/protobuf/internal/python_message.py
#
#                          func_name  \
# ...

# %%
frames = [df,test,valid]

# %%
df = pd.concat(frames)

# %%
df
# Out:
#                             repo  \
# 0      ageitgey/face_recognition
# 1      ageitgey/face_recognition
# 2      ageitgey/face_recognition
# 3      ageitgey/face_recognition
# 4      ageitgey/face_recognition
# ...                          ...
# 23102          xnuinside/clifier
# 23103          xnuinside/clifier
# 23104        tklovett/PyShirtsIO
# 23105                ibelie/typy
# 23106                ibelie/typy
#
#                                                   path  \
# 0                     examples/face_recognition_knn.py
# 1                     examples/face_recognition_knn.py
# 2                     examples/face_recognition_knn.py
# 3                              face_recognition/api.py
# 4                              face_recognition/api.py
# ...                                                ...
# 23102                               clifier/clifier.py
# 23103                               clifier/clifier.py
# 23104                           interactive_console.py
# ...

# %%
df1 = df[["code","url"]]

# %%
df1.tail()
# Out:
#                                                     code  \
# 23102  def show_version(self):\n        """ custom co...
# 23103  def check_path_action(self):\n        """ cust...
# 23104  def new_user(yaml_path):\n    '''\n    Return ...
# 23105  def _AddPropertiesForExtensions(descriptor, cl...
# 23106  def _InternalUnpackAny(msg):\n  """Unpacks Any...
#
#                                                      url
# 23102  https://github.com/xnuinside/clifier/blob/3d70...
# 23103  https://github.com/xnuinside/clifier/blob/3d70...
# 23104  https://github.com/tklovett/PyShirtsIO/blob/ff...
# 23105  https://github.com/ibelie/typy/blob/3616845fb9...
# 23106  https://github.com/ibelie/typy/blob/3616845fb9...

# %%
df1.iloc[44010][0]
# Out:
# 'def main(argv):\n    """Entry point for running one selfplay game."""\n    del argv  # Unused\n    flags.mark_flag_as_required(\'load_file\')\n\n    run_game(\n        load_file=FLAGS.load_file,\n        selfplay_dir=FLAGS.selfplay_dir,\n        holdout_dir=FLAGS.holdout_dir,\n        holdout_pct=FLAGS.holdout_pct,\n        sgf_dir=FLAGS.sgf_dir)'

# %%
df1.reset_index()
# Out:
#         index                                               code  \
# 0           0  def train(train_dir, model_save_path=None, n_n...
# 1           1  def predict(X_img_path, knn_clf=None, model_pa...
# 2           2  def show_prediction_labels_on_image(img_path, ...
# 3           3  def _rect_to_css(rect):\n    """\n    Convert ...
# 4           4  def _trim_css_to_bounds(css, image_shape):\n  ...
# ...       ...                                                ...
# 457456  23102  def show_version(self):\n        """ custom co...
# 457457  23103  def check_path_action(self):\n        """ cust...
# 457458  23104  def new_user(yaml_path):\n    '''\n    Return ...
# 457459  23105  def _AddPropertiesForExtensions(descriptor, cl...
# 457460  23106  def _InternalUnpackAny(msg):\n  """Unpacks Any...
#
#                                                       url
# 0       https://github.com/ageitgey/face_recognition/b...
# 1       https://github.com/ageitgey/face_recognition/b...
# ...

# %%
df1 =df1.reset_index(drop=True)

# %%
df1
# Out:
#                                                      code  \
# 0       def train(train_dir, model_save_path=None, n_n...
# 1       def predict(X_img_path, knn_clf=None, model_pa...
# 2       def show_prediction_labels_on_image(img_path, ...
# 3       def _rect_to_css(rect):\n    """\n    Convert ...
# 4       def _trim_css_to_bounds(css, image_shape):\n  ...
# ...                                                   ...
# 457456  def show_version(self):\n        """ custom co...
# 457457  def check_path_action(self):\n        """ cust...
# 457458  def new_user(yaml_path):\n    '''\n    Return ...
# 457459  def _AddPropertiesForExtensions(descriptor, cl...
# 457460  def _InternalUnpackAny(msg):\n  """Unpacks Any...
#
#                                                       url
# 0       https://github.com/ageitgey/face_recognition/b...
# 1       https://github.com/ageitgey/face_recognition/b...
# 2       https://github.com/ageitgey/face_recognition/b...
# ...

# %%
df1.iloc[457460][1]
# Out:
# 'https://github.com/ibelie/typy/blob/3616845fb91459aacd8df6bf82c5d91f4542bee7/typy/google/protobuf/internal/python_message.py#L916-L947'

# %%
df1.to_csv("codegit.csv")

# %%
test = pd.read_csv('codegit.csv')

# %%
test
# Out:
#         Unnamed: 0                                               code  \
# 0                0  def train(train_dir, model_save_path=None, n_n...
# 1                1  def predict(X_img_path, knn_clf=None, model_pa...
# 2                2  def show_prediction_labels_on_image(img_path, ...
# 3                3  def _rect_to_css(rect):\n    """\n    Convert ...
# 4                4  def _trim_css_to_bounds(css, image_shape):\n  ...
# ...            ...                                                ...
# 457456      457456  def show_version(self):\n        """ custom co...
# 457457      457457  def check_path_action(self):\n        """ cust...
# 457458      457458  def new_user(yaml_path):\n    '''\n    Return ...
# 457459      457459  def _AddPropertiesForExtensions(descriptor, cl...
# 457460      457460  def _InternalUnpackAny(msg):\n  """Unpacks Any...
#
#                                                       url
# 0       https://github.com/ageitgey/face_recognition/b...
# ...

# %%
df1
# Out:
#                                                      code  \
# 0       def train(train_dir, model_save_path=None, n_n...
# 1       def predict(X_img_path, knn_clf=None, model_pa...
# 2       def show_prediction_labels_on_image(img_path, ...
# 3       def _rect_to_css(rect):\n    """\n    Convert ...
# 4       def _trim_css_to_bounds(css, image_shape):\n  ...
# ...                                                   ...
# 457456  def show_version(self):\n        """ custom co...
# 457457  def check_path_action(self):\n        """ cust...
# 457458  def new_user(yaml_path):\n    '''\n    Return ...
# 457459  def _AddPropertiesForExtensions(descriptor, cl...
# 457460  def _InternalUnpackAny(msg):\n  """Unpacks Any...
#
#                                                       url
# 0       https://github.com/ageitgey/face_recognition/b...
# 1       https://github.com/ageitgey/face_recognition/b...
# 2       https://github.com/ageitgey/face_recognition/b...
# ...
